# %% [markdown]
# ### 1. Include libraries

# %%
import os
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. RELATIVE PATHS

# %%
HOME = os.getcwd()
print('HOME', HOME)

DATASET_PATH = os.path.join(HOME, 'raw_animes_dataset')
print('DATASET FOLDER', DATASET_PATH)

ANIME_DATASET_2023 = os.path.join(DATASET_PATH, 'anime-dataset-2023.csv')
print('ANIME DATASET 2023', ANIME_DATASET_2023)
# Out:
# HOME c:\Users\ADMIN\Desktop\Final_Project_DataScienceProgramming-main
# DATASET FOLDER c:\Users\ADMIN\Desktop\Final_Project_DataScienceProgramming-main\raw_animes_dataset
# ANIME DATASET 2023 c:\Users\ADMIN\Desktop\Final_Project_DataScienceProgramming-main\raw_animes_dataset\anime-dataset-2023.csv

# %% [markdown]
# ### 3. Read file into raw_anime_df

# %%
raw_anime_df = pd.read_csv(ANIME_DATASET_2023, )
raw_anime_df.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
### Số dòng, số cột
raw_anime_df.shape
# Out:
# (24905, 24)

# %% [markdown]
# ### 4. Drop unvalued columns

# %%
raw_anime_df = raw_anime_df.drop(columns=['anime_id', 'English name', 'Other name', 'Status', 'Licensors', 'Premiered'])
raw_anime_df.head()
# Out:
#                               Name Score  \
# 0                     Cowboy Bebop  8.75
# 1  Cowboy Bebop: Tengoku no Tobira  8.38
# 2                           Trigun  8.22
# 3               Witch Hunter Robin  7.25
# 4                   Bouken Ou Beet  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  \
# 0   Apr 3, 1998 to Apr 24, 1999
# 1                   Sep 1, 2001
# 2   Apr 1, 1998 to Sep 30, 1998
# 3   Jul 3, 2002 to Dec 25, 2002
# 4  Sep 30, 2004 to Sep 29, 2005
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  Bandai Visual, Dentsu, Victor Entertainment, T...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source       Duration                          Rating    Rank  \
# 0  Original  24 min per ep  R - 17+ (violence & profanity)    41.0
# 1  Original    1 hr 55 min  R - 17+ (violence & profanity)   189.0
# 2     Manga  24 min per ep       PG-13 - Teens 13 or older   328.0
# 3  Original  25 min per ep       PG-13 - Teens 13 or older  2764.0
# 4     Manga  23 min per ep                   PG - Children  4240.0
#
#    Popularity  Favorites Scored By  Members  \
# 0          43      78525  914193.0  1771505
# 1         602       1448  206248.0   360978
# 2         246      15035  356739.0   727252
# 3        1795        613   42829.0   111931
# 4        5126         14    6413.0    15001
#
#                                            Image URL
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/7/203...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...

# %%
### Số dòng, số cột
raw_anime_df.shape
# Out:
# (24905, 18)

# %% [markdown]
# ### 5. Check duplicate rows

# %%
duplicate_rows = raw_anime_df[raw_anime_df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Name, Score, Genres, Synopsis, Type, Episodes, Aired, Producers, Studios, Source, Duration, Rating, Rank, Popularity, Favorites, Scored By, Members, Image URL]
# Index: []

# %% [markdown]
# ### 6. Remove Unknown values

# %% [markdown]
# #### Kiểm tra Unknown Values

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:
# Name              0
# Score          9213
# Genres         4929
# Synopsis          0
# Type             74
# Episodes        611
# Aired             0
# Producers     13350
# Studios       10526
# Source         3689
# Duration        663
# Rating          669
# Rank           4612
# Popularity        0
# Favorites         0
# Scored By      9213
# Members           0
# Image URL         0
# dtype: int64

# %% [markdown]
# #### Visualize the number of anime has Score is UNKNOWN

# %%
unknown_score_count = (raw_anime_df['Score']=='UNKNOWN').sum()
valid_score_count = (raw_anime_df['Score']).count() - unknown_score_count

ratio = unknown_score_count/valid_score_count * 100

print(f'The ratio of unknown score and valid score: {ratio}%')

counts = [unknown_score_count, valid_score_count]
labels = ['UNKNOW', 'VALID']

# Plot the data
plt.bar(labels, counts, color = ['red', 'blue'])
plt.title('Number of Anime by Score Status')
plt.ylabel('Count')
plt.show()
# Out:
# The ratio of unknown score and valid score: 58.7114453224573%

# %% [markdown]
# ### Because the ratio is so big, so delete rows has Score is 'UNKNOWN'

# %%
# Check the shape of origin datasets
print('Shape of origin dataset', raw_anime_df.shape)

# Check the shape of dataset after drop rows
raw_anime_df = raw_anime_df[raw_anime_df['Score']!='UNKNOWN']
print('Shape of datasets after droping raws', raw_anime_df.shape)
# Out:
# Shape of origin dataset (24905, 18)
# Shape of datasets after droping raws (15692, 18)

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:
# Name             0
# Score            0
# Genres        1753
# Synopsis         0
# Type             1
# Episodes        88
# Aired            0
# Producers     6087
# Studios       3527
# Source        1735
# Duration        15
# Rating          94
# Rank          2991
# Popularity       0
# Favorites        0
# Scored By        0
# Members          0
# Image URL        0
# dtype: int64

# %% [markdown]
# ### Remove Genres values
# Xóa các giá trị UNKNOWN trong cột Genres

# %%
# Drop các giá trị Unknown trong cột Genres
# Check the shape of origin datasets
print('Shape of origin dataset', raw_anime_df.shape)

# Check the shape of dataset after drop rows
raw_anime_df = raw_anime_df[raw_anime_df['Genres']!='UNKNOWN']
print('Shape of datasets after droping raws', raw_anime_df.shape)
# Out:
# Shape of origin dataset (15692, 18)
# Shape of datasets after droping raws (13939, 18)

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:
# Name             0
# Score            0
# Genres           0
# Synopsis         0
# Type             1
# Episodes        86
# Aired            0
# Producers     5076
# Studios       2379
# Source        1541
# Duration        14
# Rating          86
# Rank          1909
# Popularity       0
# Favorites        0
# Scored By        0
# Members          0
# Image URL        0
# dtype: int64

# %% [markdown]
# ### Fill Type values
# Điền giá trị cho type values

# %%
type_unknown_value = raw_anime_df[(raw_anime_df['Type'] == 'UNKNOWN') | (raw_anime_df['Type'] == 'Unknown')]
type_unknown_value
# Out:
#                      Name Score   Genres  \
# 4978  Sekai Meisaku Douwa  6.08  Fantasy
#
#                                                Synopsis     Type Episodes  \
# 4978  Another of Toei's World Famous Fairy Tale seri...  UNKNOWN     20.0
#
#                      Aired Producers  Studios   Source       Duration  \
# 4978  Oct 1975 to Feb 1983   UNKNOWN  UNKNOWN  Unknown  10 min per ep
#
#             Rating    Rank  Popularity  Favorites Scored By  Members  \
# 4978  G - All Ages  8485.0       13677          2     158.0      729
#
#                                               Image URL
# 4978  https://cdn.myanimelist.net/images/anime/10/17...

# %% [markdown]
# Nhóm thấy được có 1 bộ duy nhất không có Type, nhưng bộ này có Episodes = 20 -> Nhóm sẽ điền Type là TV

# %%
raw_anime_df.loc[(raw_anime_df['Type'] == 'UNKNOWN') | (raw_anime_df['Type'] == 'Unknown'), 'Type'] = 'TV'

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:
# Name             0
# Score            0
# Genres           0
# Synopsis         0
# Type             0
# Episodes        86
# Aired            0
# Producers     5076
# Studios       2379
# Source        1541
# Duration        14
# Rating          86
# Rank          1909
# Popularity       0
# Favorites        0
# Scored By        0
# Members          0
# Image URL        0
# dtype: int64

# %% [markdown]
# ### Remove Duration values (Time per ep)
# Xóa các giá trị UNKNOWN trong cột Duration

# %%
# Check the shape of origin datasets
print('Shape of origin dataset', raw_anime_df.shape)

# Check the shape of dataset after drop rows
raw_anime_df = raw_anime_df[raw_anime_df['Duration']!='Unknown']
print('Shape of datasets after droping raws', raw_anime_df.shape)
# Out:
# Shape of origin dataset (13939, 18)
# Shape of datasets after droping raws (13925, 18)

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' hoặc 'Unknown' trong từng cột:
# Name             0
# Score            0
# Genres           0
# Synopsis         0
# Type             0
# Episodes        83
# Aired            0
# Producers     5068
# Studios       2375
# Source        1540
# Duration         0
# Rating          86
# Rank          1908
# Popularity       0
# Favorites        0
# Scored By        0
# Members          0
# Image URL        0
# dtype: int64

# %% [markdown]
# #### Modify value for Duration:

# %%
import re

# Hàm chuyển đổi chuỗi thời gian thành số phút
def convert_to_minutes(time_str):
    total_minutes = 0
    
    # Tìm tất cả các phần giờ, phút và giây trong chuỗi
    hours_match = re.search(r'(\d+)\s*hr', time_str)
    minutes_match = re.search(r'(\d+)\s*min', time_str)
    seconds_match = re.search(r'(\d+)\s*sec', time_str)
    
    # Thêm số phút từ phần 'min'
    if minutes_match:
        total_minutes += int(minutes_match.group(1))
    
    # Thêm số phút từ phần 'hr' nếu có
    if hours_match:
        total_minutes += int(hours_match.group(1)) * 60
    
    # Thêm số phút từ phần 'sec' nếu có
    if seconds_match:
        total_minutes += round(int(seconds_match.group(1)) / 60, 2)
    
    return total_minutes

# Áp dụng hàm chuyển đổi cho cột Duration và đổi tên cột
raw_anime_df['Duration'] = raw_anime_df['Duration'].apply(convert_to_minutes)
raw_anime_df.rename(columns={'Duration': 'Time per ep (Min)'}, inplace=True)

# In ra DataFrame đã xử lý
raw_anime_df
# Out:
#                                                     Name Score  \
# 0                                           Cowboy Bebop  8.75
# 1                        Cowboy Bebop: Tengoku no Tobira  8.38
# 2                                                 Trigun  8.22
# 3                                     Witch Hunter Robin  7.25
# 4                                         Bouken Ou Beet  6.94
# ...                                                  ...   ...
# 24539  One Piece: Dai Gekisen Tokushuu! Zoro vs. Ooka...  6.47
# 24557         Gensou Mangekyou: The Memories of Phantasm  7.78
# 24579        Mashle: Mash Burnedead to Fushigi na Tegami  5.84
# 24590  Li Shi Zhentan Shiwusuo: A Day in Lungmen - Ho...  5.99
# 24831  One Piece: Dai Gekisen Tokushuu! Hangeki Doume...  6.29
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 1                            Action, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 4          Adventure, Fantasy, Supernatural
# ...                                     ...
# 24539    Action, Adventure, Comedy, Fantasy
# 24557                               Fantasy
# 24579               Action, Comedy, Fantasy
# 24590               Action, Comedy, Mystery
# 24831    Action, Adventure, Comedy, Fantasy
#
#                                                 Synopsis     Type Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...       TV     26.0
# 1      Another day, another bounty—such is the life o...    Movie      1.0
# 2      Vash the Stampede is the man with a $$60,000,0...       TV     26.0
# 3      Robin Sena is a powerful craft user drafted in...       TV     26.0
# 4      It is the dark century and the people are suff...       TV     52.0
# ...                                                  ...      ...      ...
# 24539     This is the 7th recap special of the Wano arc.  Special      1.0
# 24557  Marisa, an ordinary magician, suspects a youka...      OVA     18.0
# 24579         Recap of the first six episodes of Mashle.  Special      1.0
# 24590  Infiltrating, disguising, and raiding. Tonight...      ONA      1.0
# 24831     This is the 8th recap special of the Wano arc.  Special      1.0
#
#                               Aired  \
# 0       Apr 3, 1998 to Apr 24, 1999
# 1                       Sep 1, 2001
# 2       Apr 1, 1998 to Sep 30, 1998
# 3       Jul 3, 2002 to Dec 25, 2002
# 4      Sep 30, 2004 to Sep 29, 2005
# ...                             ...
# 24539                  May 14, 2023
# 24557   Aug 12, 2011 to May 7, 2023
# 24579                  May 20, 2023
# 24590                  Oct 24, 2021
# 24831                  Jun 18, 2023
#
#                                                Producers             Studios  \
# 0                                          Bandai Visual             Sunrise
# 1                                 Sunrise, Bandai Visual               Bones
# 2                                   Victor Entertainment            Madhouse
# 3      Bandai Visual, Dentsu, Victor Entertainment, T...             Sunrise
# 4                                       TV Tokyo, Dentsu      Toei Animation
# ...                                                  ...                 ...
# 24539                                            UNKNOWN      Toei Animation
# 24557                                            UNKNOWN             UNKNOWN
# 24579                                            UNKNOWN        A-1 Pictures
# 24590                                            UNKNOWN  HMCH, Gravity Well
# 24831                                            UNKNOWN             UNKNOWN
#
#          Source  Time per ep (Min)                          Rating    Rank  \
# 0      Original               24.0  R - 17+ (violence & profanity)    41.0
# 1      Original              115.0  R - 17+ (violence & profanity)   189.0
# 2         Manga               24.0       PG-13 - Teens 13 or older   328.0
# 3      Original               25.0       PG-13 - Teens 13 or older  2764.0
# 4         Manga               23.0                   PG - Children  4240.0
# ...         ...                ...                             ...     ...
# 24539     Manga               24.0       PG-13 - Teens 13 or older  6536.0
# 24557      Game               16.0       PG-13 - Teens 13 or older   963.0
# 24579     Manga               23.0       PG-13 - Teens 13 or older  9552.0
# 24590      Game                3.0       PG-13 - Teens 13 or older  8891.0
# 24831     Manga               24.0       PG-13 - Teens 13 or older  7480.0
#
#        Popularity  Favorites Scored By  Members  \
# 0              43      78525  914193.0  1771505
# 1             602       1448  206248.0   360978
# 2             246      15035  356739.0   727252
# 3            1795        613   42829.0   111931
# 4            5126         14    6413.0    15001
# ...           ...        ...       ...      ...
# 24539       11725          1     722.0     1367
# 24557        9993         68     662.0     2492
# 24579        8772         10    1971.0     3828
# 24590       14796          1     129.0      518
# 24831       14291          1     320.0      593
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24539  https://cdn.myanimelist.net/images/anime/1197/...
# 24557  https://cdn.myanimelist.net/images/anime/1729/...
# 24579  https://cdn.myanimelist.net/images/anime/1097/...
# 24590  https://cdn.myanimelist.net/images/anime/1865/...
# 24831  https://cdn.myanimelist.net/images/anime/1981/...
#
# [13925 rows x 18 columns]

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' trong từng cột:
# Name                    0
# Score                   0
# Genres                  0
# Synopsis                0
# Type                    0
# Episodes               83
# Aired                   0
# Producers            5068
# Studios              2375
# Source               1540
# Time per ep (Min)       0
# Rating                 86
# Rank                 1908
# Popularity              0
# Favorites               0
# Scored By               0
# Members                 0
# Image URL               0
# dtype: int64

# %% [markdown]
# ### Modified Aired và Duration columns -> Make 2 column as Realeased date and Completed date

# %%
### Kiểm tra có bao nhiêu dòng có dữ liệu Aired là Not available
not_available_rows = raw_anime_df[raw_anime_df['Aired'] == 'Not available']
print(not_available_rows.shape)
# Out:
# (5, 18)

# %%
### Lấy các dòng không có dữ liệu Aired là Not available
raw_anime_df = raw_anime_df[raw_anime_df['Aired'] != 'Not available']
print(raw_anime_df.shape)
# Out:
# (13920, 18)

# %%
def preprocess_published(df):
    """
    Preprocesses the 'Published' column in the DataFrame.

    Args:
        df: The DataFrame containing the 'Published' column.

    Returns:
        The DataFrame with 'Released date' and 'Completed date' columns preprocessed.
    """
    def parse_single_date(date_str, is_start_date=True):
        if "," in date_str:
          parts = date_str.split(",")
          if len(parts) == 2 and parts[0].isdigit() and len(parts[0].strip()) <= 2:  # "12, 1999"
              try:
                  month = int(parts[0].strip())
                  year = int(parts[1].strip())
                  if 1 <= month <= 12:  # Nếu tháng hợp lệ
                      return f"{year:04d}-{month:02d}-01"  # Chuyển thành "YYYY-MM-DD"
              except ValueError:
                  pass
        for fmt in ["%b %d, %Y", "%b %Y", "%Y", "%b-%y"]:
            try:
                return datetime.strptime(date_str, fmt).strftime("%Y-%m-%d")
            except ValueError:
                continue
        return "Unknown" if is_start_date else "Updating"

    def parse_published(published_str):
        if not isinstance(published_str, str) or not published_str.strip():
            return "Unknown", "Updating"

        published_str = published_str.strip()

        if 'to' in published_str:
            try:
                start_date_str, end_date_str = map(str.strip, published_str.split('to'))
            except ValueError:
                return "Unknown", "Updating"

            start_date = parse_single_date(start_date_str, is_start_date=True)
            end_date = parse_single_date(end_date_str, is_start_date=False)
            return start_date, end_date
        else:
            start_date = parse_single_date(published_str, is_start_date=True)
            return start_date, "Updating"

    # Áp dụng hàm xử lý và tạo hai cột mới
    df['Released date'], df['Completed date'] = zip(*df['Aired'].apply(parse_published))
    return df

raw_anime_df = preprocess_published(raw_anime_df)
raw_anime_df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10444\4209164729.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Released date'], df['Completed date'] = zip(*df['Aired'].apply(parse_published))
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10444\4209164729.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Released date'], df['Completed date'] = zip(*df['Aired'].apply(parse_published))
#                               Name Score  \
# 0                     Cowboy Bebop  8.75
# 1  Cowboy Bebop: Tengoku no Tobira  8.38
# 2                           Trigun  8.22
# 3               Witch Hunter Robin  7.25
# 4                   Bouken Ou Beet  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  \
# 0   Apr 3, 1998 to Apr 24, 1999
# 1                   Sep 1, 2001
# 2   Apr 1, 1998 to Sep 30, 1998
# 3   Jul 3, 2002 to Dec 25, 2002
# 4  Sep 30, 2004 to Sep 29, 2005
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  Bandai Visual, Dentsu, Victor Entertainment, T...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source  Time per ep (Min)                          Rating    Rank  \
# 0  Original               24.0  R - 17+ (violence & profanity)    41.0
# 1  Original              115.0  R - 17+ (violence & profanity)   189.0
# 2     Manga               24.0       PG-13 - Teens 13 or older   328.0
# 3  Original               25.0       PG-13 - Teens 13 or older  2764.0
# 4     Manga               23.0                   PG - Children  4240.0
#
#    Popularity  Favorites Scored By  Members  \
# 0          43      78525  914193.0  1771505
# 1         602       1448  206248.0   360978
# 2         246      15035  356739.0   727252
# 3        1795        613   42829.0   111931
# 4        5126         14    6413.0    15001
#
#                                            Image URL Released date  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...    1998-04-03
# 1  https://cdn.myanimelist.net/images/anime/1439/...    2001-09-01
# 2  https://cdn.myanimelist.net/images/anime/7/203...    1998-04-01
# 3  https://cdn.myanimelist.net/images/anime/10/19...    2002-07-03
# 4  https://cdn.myanimelist.net/images/anime/7/215...    2004-09-30
#
#   Completed date
# 0     1999-04-24
# 1       Updating
# 2     1998-09-30
# 3     2002-12-25
# 4     2005-09-29

# %%
### Nếu Aired chỉ có 1 ngày duy nhất, thì Published date và Completed date là cùng 1 ngày
def update_completed_date(row):
    """Updates 'Completed date' based on 'Published' and 'Completed date'."""
    if 'to' not in str(row['Aired']) and row['Completed date'] == 'Updating':
        return row['Released date']
    return row['Completed date']

raw_anime_df['Completed date'] = raw_anime_df.apply(update_completed_date, axis=1)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10444\1767933409.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_anime_df['Completed date'] = raw_anime_df.apply(update_completed_date, axis=1)

# %%
raw_anime_df.head()
# Out:
#                               Name Score  \
# 0                     Cowboy Bebop  8.75
# 1  Cowboy Bebop: Tengoku no Tobira  8.38
# 2                           Trigun  8.22
# 3               Witch Hunter Robin  7.25
# 4                   Bouken Ou Beet  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  \
# 0   Apr 3, 1998 to Apr 24, 1999
# 1                   Sep 1, 2001
# 2   Apr 1, 1998 to Sep 30, 1998
# 3   Jul 3, 2002 to Dec 25, 2002
# 4  Sep 30, 2004 to Sep 29, 2005
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  Bandai Visual, Dentsu, Victor Entertainment, T...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source  Time per ep (Min)                          Rating    Rank  \
# 0  Original               24.0  R - 17+ (violence & profanity)    41.0
# 1  Original              115.0  R - 17+ (violence & profanity)   189.0
# 2     Manga               24.0       PG-13 - Teens 13 or older   328.0
# 3  Original               25.0       PG-13 - Teens 13 or older  2764.0
# 4     Manga               23.0                   PG - Children  4240.0
#
#    Popularity  Favorites Scored By  Members  \
# 0          43      78525  914193.0  1771505
# 1         602       1448  206248.0   360978
# 2         246      15035  356739.0   727252
# 3        1795        613   42829.0   111931
# 4        5126         14    6413.0    15001
#
#                                            Image URL Released date  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...    1998-04-03
# 1  https://cdn.myanimelist.net/images/anime/1439/...    2001-09-01
# 2  https://cdn.myanimelist.net/images/anime/7/203...    1998-04-01
# 3  https://cdn.myanimelist.net/images/anime/10/19...    2002-07-03
# 4  https://cdn.myanimelist.net/images/anime/7/215...    2004-09-30
#
#   Completed date
# 0     1999-04-24
# 1     2001-09-01
# 2     1998-09-30
# 3     2002-12-25
# 4     2005-09-29

# %% [markdown]
# ### Fill Episodes

# %% [markdown]
# #### Check rows has Episodes is UNKNOWN

# %%
unknown_data = raw_anime_df[raw_anime_df['Episodes']=='UNKNOWN']
unknown_data
# Out:
#                                                     Name Score  \
# 11                                             One Piece  8.69
# 211                                      Detective Conan  8.17
# 871                                     Crayon Shin-chan  7.77
# 1093                                    Nintama Rantarou  7.07
# 1787                                  Sore Ike! Anpanman  6.53
# ...                                                  ...   ...
# 23787    Fate/Grand Order: Fujimaru Ritsuka wa Wakaranai   7.0
# 23900                     Yoru wa Neko to Issho Season 2  6.79
# 24140                        Fushigi no Kuni no Succubus  5.72
# 24143  Maid Kyouiku: Botsuraku Kizoku Rurikawa Tsubak...  6.69
# 24262     Nightmare x Deathscythe: Hangyaku no Resonance  5.39
#
#                            Genres  \
# 11     Action, Adventure, Fantasy
# 211    Adventure, Comedy, Mystery
# 871                 Comedy, Ecchi
# 1093                       Comedy
# 1787              Comedy, Fantasy
# ...                           ...
# 23787                      Comedy
# 23900                      Comedy
# 24140             Fantasy, Hentai
# 24143                      Hentai
# 24262                      Hentai
#
#                                                 Synopsis Type Episodes  \
# 11     Gol D. Roger was known as the "Pirate King," t...   TV  UNKNOWN
# 211    Shinichi Kudou, a high school student of astou...   TV  UNKNOWN
# 871    There is no such thing as an uneventful day in...   TV  UNKNOWN
# 1093   Taking place in the Sengoku Period, Rantarou, ...   TV  UNKNOWN
# 1787   One night, a Star of Life falls down the chimn...   TV  UNKNOWN
# ...                                                  ...  ...      ...
# 23787  Ritsuka Fujimaru—humanity's last master. It wo...  ONA  UNKNOWN
# 23900            Second season of Yoru wa Neko to Issho.  ONA  UNKNOWN
# 24140           No description available for this anime.  OVA  UNKNOWN
# 24143  After the Rurikawa clan fell into disgrace, th...  OVA  UNKNOWN
# 24262           No description available for this anime.  OVA  UNKNOWN
#
#                    Aired                                      Producers  \
# 11     Oct 20, 1999 to ?                         Fuji TV, TAP, Shueisha
# 211     Jan 8, 1996 to ?  Yomiuri Telecasting, TMS-Kyokuchi, Shogakukan
# 871    Apr 13, 1992 to ?                                       TV Asahi
# 1093   Apr 10, 1993 to ?                                            NHK
# 1787    Oct 3, 1988 to ?               Sotsu, Nippon Television Network
# ...                  ...                                            ...
# 23787   Feb 4, 2023 to ?                            Notes, INSPION Edge
# 23900   Mar 8, 2023 to ?                                       Kadokawa
# 24140  May 26, 2023 to ?                                        UNKNOWN
# 24143  May 26, 2023 to ?                                 Pink Pineapple
# 24262  May 26, 2023 to ?                           Mediabank, Gold Bear
#
#                     Studios        Source  Time per ep (Min)  \
# 11           Toei Animation         Manga               24.0
# 211       TMS Entertainment         Manga               25.0
# 871       Shin-Ei Animation         Manga               21.0
# 1093                Ajia-do         Manga               10.0
# 1787      TMS Entertainment  Picture book               24.0
# ...                     ...           ...                ...
# 23787                   DLE         Manga                2.0
# 23900        Studio PuYUKAI     Web manga                2.0
# 24140                 Majin          Game               20.0
# 24143            Studio 1st         Manga               20.0
# 24262  Anime Antenna Iinkai  Visual novel               30.0
#
#                           Rating     Rank  Popularity  Favorites  Scored By  \
# 11     PG-13 - Teens 13 or older     55.0          20     198986  1226493.0
# 211    PG-13 - Teens 13 or older    382.0         653      13964   154061.0
# 871                 G - All Ages    972.0        2228       1178    39023.0
# 1093                G - All Ages   3681.0        6925         68     2346.0
# 1787               PG - Children   6222.0        8982         25     1146.0
# ...                          ...      ...         ...        ...        ...
# 23787  PG-13 - Teens 13 or older   4008.0        8091         13      386.0
# 23900               G - All Ages   4889.0       10132          1      402.0
# 24140                Rx - Hentai  UNKNOWN       11508          2      241.0
# 24143                Rx - Hentai  UNKNOWN       10305         12      421.0
# 24262                Rx - Hentai  UNKNOWN       13474          1      122.0
#
#        Members                                          Image URL  \
# 11     2168904  https://cdn.myanimelist.net/images/anime/6/732...
# 211     334559  https://cdn.myanimelist.net/images/anime/7/751...
# 871      79676  https://cdn.myanimelist.net/images/anime/10/59...
# 1093      7180  https://cdn.myanimelist.net/images/anime/6/740...
# 1787      3545  https://cdn.myanimelist.net/images/anime/1902/...
# ...        ...                                                ...
# 23787     4892  https://cdn.myanimelist.net/images/anime/1800/...
# 23900     2377  https://cdn.myanimelist.net/images/anime/1557/...
# 24140     1471  https://cdn.myanimelist.net/images/anime/1953/...
# 24143     2253  https://cdn.myanimelist.net/images/anime/1394/...
# 24262      779  https://cdn.myanimelist.net/images/anime/1013/...
#
#       Released date Completed date
# 11       1999-10-20       Updating
# 211      1996-01-08       Updating
# 871      1992-04-13       Updating
# 1093     1993-04-10       Updating
# 1787     1988-10-03       Updating
# ...             ...            ...
# 23787    2023-02-04       Updating
# 23900    2023-03-08       Updating
# 24140    2023-05-26       Updating
# 24143    2023-05-26       Updating
# 24262    2023-05-26       Updating
#
# [83 rows x 20 columns]

# %% [markdown]
# ### Modified duration

# %%
raw_anime_df = raw_anime_df.sort_values(by=['Released date'], ascending=[True])

# Reset lại index bắt đầu từ 0
raw_anime_df = raw_anime_df.reset_index(drop=True)

raw_anime_df.head()
# Out:
#                                    Name Score         Genres  \
# 0     Imokawa Mukuzo: Genkanban no Maki  5.28         Comedy
# 1  Dekobou Shingachou: Meian no Shippai  5.77         Comedy
# 2                Saru to Kani no Gassen  4.83          Drama
# 3                       Namakura Gatana   5.5         Comedy
# 4                        Hanasaka Jijii   4.8  Comedy, Drama
#
#                                             Synopsis   Type Episodes  \
# 0  The third professionally produced Japanese ani...  Movie      1.0
# 1  A man first realizes he's born to be a samurai...  Movie      1.0
# 2  A monkey tricks a crab and steals his food. Mo...  Movie      1.0
# 3  Namakura Gatana, meaning "dull-edged sword," i...  Movie      1.0
# 4  Short movie produced by the first generation a...  Movie      1.0
#
#            Aired                              Producers  Studios    Source  \
# 0  Jan 1917 to ?  Tenkatsu Tennenshoku Katsudou Shashin  UNKNOWN  Original
# 1  Feb 1917 to ?                                UNKNOWN  UNKNOWN  Original
# 2   May 20, 1917                                UNKNOWN  UNKNOWN     Other
# 3   Jun 30, 1917                                UNKNOWN  UNKNOWN  Original
# 4   Aug 26, 1917                                UNKNOWN  UNKNOWN     Other
#
#    Time per ep (Min)        Rating     Rank  Popularity  Favorites Scored By  \
# 0                8.0  G - All Ages  11399.0       12585          2     353.0
# 1                5.0  G - All Ages   9816.0       11619         10     575.0
# 2                6.0  G - All Ages  12162.0       12621          1     383.0
# 3                4.0  G - All Ages  10771.0        6371         11    5344.0
# 4                6.0  G - All Ages  12200.0       12203          0     514.0
#
#    Members                                          Image URL Released date  \
# 0     1017  https://cdn.myanimelist.net/img/sp/icon/apple-...    1917-01-01
# 1     1414  https://cdn.myanimelist.net/img/sp/icon/apple-...    1917-02-01
# 2     1007  https://cdn.myanimelist.net/images/anime/4/837...    1917-05-20
# 3     8792  https://cdn.myanimelist.net/images/anime/1959/...    1917-06-30
# 4     1150  https://cdn.myanimelist.net/images/anime/5/494...    1917-08-26
#
#   Completed date
# 0       Updating
# 1       Updating
# 2     1917-05-20
# 3     1917-06-30
# 4     1917-08-26

# %% [markdown]
# Xử lí các giá trị UNKNOWN trong cột Episodes:
# - Nếu dòng có giá trị UNKNOWN đó có giá trị Type = TV -> Lấy ra max của 10 giá trị có Type là TV khác
# - Nếu dòng có giá trị UNKNOWN đó có giá trị Type là kiểu khác -> Đặt giá trị bằng 1

# %%
# Chuyển đổi cột Episodes sang số (UNKNOWN -> NaN)
raw_anime_df['Episodes'] = pd.to_numeric(raw_anime_df['Episodes'], errors='coerce')

# Lọc DataFrame chỉ chứa các dòng có Type là TV
tv_anime_df = raw_anime_df[raw_anime_df['Type'] == 'TV']

# Duyệt qua từng dòng của DataFrame gốc
for idx, value in raw_anime_df['Episodes'].items():
    if pd.isna(value) and raw_anime_df.at[idx, 'Type'] == 'TV':  # Nếu Episodes là NaN (do UNKNOWN)
        # Xác định vị trí dòng tương ứng trong DataFrame TV
        tv_indices = tv_anime_df.index  # Chỉ số của các dòng có Type là TV
        
        # Tìm vị trí của idx trong danh sách tv_indices
        if idx in tv_indices:
            position = tv_indices.get_loc(idx)  # Vị trí của idx trong danh sách tv_indices
            
            # Lấy 5 dòng trước và 5 dòng sau từ DataFrame TV
            start_pos = max(0, position - 5)
            end_pos = min(len(tv_indices), position + 5 + 1)
            
            # Lấy giá trị Episodes trong phạm vi này
            surrounding_values = raw_anime_df.loc[tv_indices[start_pos:end_pos], 'Episodes'].dropna()
            
            # Tìm giá trị lớn nhất
            max_value = surrounding_values.max() if not surrounding_values.empty else None
            
            print(f"Dòng {idx}: UNKNOWN, max trong phạm vi [TV dòng {start_pos} đến {end_pos - 1}] là {max_value}")
            
            # Thay thế giá trị UNKNOWN bằng max_value
            raw_anime_df.at[idx, 'Episodes'] = max_value
    elif pd.isna(value): 
        raw_anime_df.at[idx, 'Episodes'] = 1
# Out:
# Dòng 244: UNKNOWN, max trong phạm vi [TV dòng 37 đến 47] là 156.0
# Dòng 1313: UNKNOWN, max trong phạm vi [TV dòng 436 đến 446] là 164.0
# Dòng 1783: UNKNOWN, max trong phạm vi [TV dòng 537 đến 547] là 170.0
# Dòng 1928: UNKNOWN, max trong phạm vi [TV dòng 565 đến 575] là 170.0
# Dòng 2182: UNKNOWN, max trong phạm vi [TV dòng 607 đến 617] là 55.0
# Dòng 2220: UNKNOWN, max trong phạm vi [TV dòng 624 đến 634] là 52.0
# Dòng 2319: UNKNOWN, max trong phạm vi [TV dòng 644 đến 654] là 114.0
# Dòng 2750: UNKNOWN, max trong phạm vi [TV dòng 765 đến 775] là 26.0
# Dòng 2969: UNKNOWN, max trong phạm vi [TV dòng 862 đến 872] là 68.0
# Dòng 4561: UNKNOWN, max trong phạm vi [TV dòng 1353 đến 1363] là 50.0
# Dòng 6464: UNKNOWN, max trong phạm vi [TV dòng 1990 đến 2000] là 52.0
# Dòng 8584: UNKNOWN, max trong phạm vi [TV dòng 2578 đến 2588] là 51.0
# Dòng 9808: UNKNOWN, max trong phạm vi [TV dòng 2961 đến 2971] là 100.0
# Dòng 12463: UNKNOWN, max trong phạm vi [TV dòng 3820 đến 3830] là 24.0
# Dòng 13224: UNKNOWN, max trong phạm vi [TV dòng 4061 đến 4071] là 13.0
# Dòng 13357: UNKNOWN, max trong phạm vi [TV dòng 4098 đến 4108] là 50.0
# Dòng 13365: UNKNOWN, max trong phạm vi [TV dòng 4103 đến 4113] là 50.0
# Dòng 13768: UNKNOWN, max trong phạm vi [TV dòng 4258 đến 4268] là 13.0
# Dòng 13771: UNKNOWN, max trong phạm vi [TV dòng 4261 đến 4271] là 13.0
# Dòng 13823: UNKNOWN, max trong phạm vi [TV dòng 4285 đến 4295] là 24.0
# Dòng 13857: UNKNOWN, max trong phạm vi [TV dòng 4291 đến 4301] là 24.0
# Dòng 13858: UNKNOWN, max trong phạm vi [TV dòng 4292 đến 4302] là 24.0
# Dòng 13900: UNKNOWN, max trong phạm vi [TV dòng 4329 đến 4336] là 24.0

# %%
raw_anime_df.to_csv("anime-processed-episodes.csv", sep=',', encoding='utf-8-sig', index=False, header=True)

# %% [markdown]
# ### Check unique values in Rating

# %%
print(raw_anime_df['Rating'].unique())

unknown_rating_count = (raw_anime_df['Rating']=='UNKNOWN').sum()
valid_rating_count = (raw_anime_df['Rating']).count() - unknown_rating_count

ratio = unknown_rating_count/valid_rating_count * 100

print('------------\n')
print(f'The ratio of unknown rating and valid rating: {ratio}%')
# Out:
# ['G - All Ages' 'PG - Children' 'R - 17+ (violence & profanity)'
#  'PG-13 - Teens 13 or older' 'R+ - Mild Nudity' 'UNKNOWN' 'Rx - Hentai']
# ------------
#
# The ratio of unknown rating and valid rating: 0.6216567876246928%

# %% [markdown]
# ### => Chú ý: Không thực hiện filling rating, type -> thực hiện model dự đoán rating, type

# %% [markdown]
# ### Check UNKNOWN values in Score By

# %%
unknown_scored_by_count = (raw_anime_df['Scored By']=='UNKNOWN').sum()
valid_scored_by_count = (raw_anime_df['Scored By']).count() - unknown_scored_by_count

ratio = unknown_scored_by_count/valid_scored_by_count * 100

print(f'The ratio of unknown Scored By and valid Scored By: {ratio}%')
# Out:
# The ratio of unknown Scored By and valid Scored By: 0.0%

# %% [markdown]
# ### Check UNKNOWN values in Rank

# %%
unknown_rank_count = (raw_anime_df['Rank']=='UNKNOWN').sum()
valid_rank_count = (raw_anime_df['Rank']).count() - unknown_rank_count

ratio = unknown_rank_count/valid_rank_count * 100

print(f'The ratio of unknown Rank and valid Rank: {ratio}%')
# Out:
# The ratio of unknown Rank and valid Rank: 15.884115884115884%

# %% [markdown]
# ### Check UNKNOWN values in dataset

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' trong từng cột:
# Name                    0
# Score                   0
# Genres                  0
# Synopsis                0
# Type                    0
# Episodes                0
# Aired                   0
# Producers            5063
# Studios              2371
# Source               1540
# Time per ep (Min)       0
# Rating                 86
# Rank                 1908
# Popularity              0
# Favorites               0
# Scored By               0
# Members                 0
# Image URL               0
# Released date           0
# Completed date          0
# dtype: int64

# %% [markdown]
# ### Remove Aired
# Xóa cột Aired do đã có cột Realeased date và Completed date thay thế

# %%
raw_anime_df = raw_anime_df.drop(columns=['Aired'])
raw_anime_df.head()
# Out:
#                                    Name Score         Genres  \
# 0     Imokawa Mukuzo: Genkanban no Maki  5.28         Comedy
# 1  Dekobou Shingachou: Meian no Shippai  5.77         Comedy
# 2                Saru to Kani no Gassen  4.83          Drama
# 3                       Namakura Gatana   5.5         Comedy
# 4                        Hanasaka Jijii   4.8  Comedy, Drama
#
#                                             Synopsis   Type  Episodes  \
# 0  The third professionally produced Japanese ani...  Movie       1.0
# 1  A man first realizes he's born to be a samurai...  Movie       1.0
# 2  A monkey tricks a crab and steals his food. Mo...  Movie       1.0
# 3  Namakura Gatana, meaning "dull-edged sword," i...  Movie       1.0
# 4  Short movie produced by the first generation a...  Movie       1.0
#
#                                Producers  Studios    Source  \
# 0  Tenkatsu Tennenshoku Katsudou Shashin  UNKNOWN  Original
# 1                                UNKNOWN  UNKNOWN  Original
# 2                                UNKNOWN  UNKNOWN     Other
# 3                                UNKNOWN  UNKNOWN  Original
# 4                                UNKNOWN  UNKNOWN     Other
#
#    Time per ep (Min)        Rating     Rank  Popularity  Favorites Scored By  \
# 0                8.0  G - All Ages  11399.0       12585          2     353.0
# 1                5.0  G - All Ages   9816.0       11619         10     575.0
# 2                6.0  G - All Ages  12162.0       12621          1     383.0
# 3                4.0  G - All Ages  10771.0        6371         11    5344.0
# 4                6.0  G - All Ages  12200.0       12203          0     514.0
#
#    Members                                          Image URL Released date  \
# 0     1017  https://cdn.myanimelist.net/img/sp/icon/apple-...    1917-01-01
# 1     1414  https://cdn.myanimelist.net/img/sp/icon/apple-...    1917-02-01
# 2     1007  https://cdn.myanimelist.net/images/anime/4/837...    1917-05-20
# 3     8792  https://cdn.myanimelist.net/images/anime/1959/...    1917-06-30
# 4     1150  https://cdn.myanimelist.net/images/anime/5/494...    1917-08-26
#
#   Completed date
# 0       Updating
# 1       Updating
# 2     1917-05-20
# 3     1917-06-30
# 4     1917-08-26

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' trong từng cột:
# Name                    0
# Score                   0
# Genres                  0
# Synopsis                0
# Type                    0
# Episodes                0
# Producers            5063
# Studios              2371
# Source               1540
# Time per ep (Min)       0
# Rating                 86
# Rank                 1908
# Popularity              0
# Favorites               0
# Scored By               0
# Members                 0
# Image URL               0
# Released date           0
# Completed date          0
# dtype: int64

# %% [markdown]
# Trước khi điền Rank, nhóm sẽ kiểm tra lại kiểu dữ liệu của data như sau:

# %%
raw_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13920 entries, 0 to 13919
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               13920 non-null  object
#  1   Score              13920 non-null  object
#  2   Genres             13920 non-null  object
#  3   Synopsis           13920 non-null  object
#  4   Type               13920 non-null  object
#  5   Episodes           13920 non-null  float64
#  6   Producers          13920 non-null  object
#  7   Studios            13920 non-null  object
#  8   Source             13920 non-null  object
#  9   Time per ep (Min)  13920 non-null  float64
#  10  Rating             13920 non-null  object
#  11  Rank               13920 non-null  object
#  12  Popularity         13920 non-null  int64
#  13  Favorites          13920 non-null  int64
#  14  Scored By          13920 non-null  object
#  15  Members            13920 non-null  int64
#  16  Image URL          13920 non-null  object
#  17  Released date      13920 non-null  object
#  18  Completed date     13920 non-null  object
# dtypes: float64(2), int64(3), object(14)
# memory usage: 2.0+ MB

# %% [markdown]
# Nhóm sẽ điều chỉnh kiểu dữ liệu lại như sau để có thể thực hiện xử lí các bước sau bình thường:
# - Name: object
# - Score: float64
# - Genres: object
# - Synopsis: object
# - Type: object
# - Episodes: float64
# - Producers: object
# - Studios: object
# - Source: object
# - Time per ep (Min): float64
# - Rating: object
# - Rank: int64
# - Popularity: float64
# - Favourites: float64
# - Scored by: float64
# - Members: float64
# - Image URL: object
# - Released date: object -> datetime
# - Completed date: object -> datetime

# %%
# Chuyển kiểu dữ liệu:
raw_anime_df = raw_anime_df.astype({
    'Name': 'object',
    'Score': 'float64',
    'Genres': 'object',
    'Synopsis': 'object',
    'Type': 'object',
    'Episodes': 'float64',
    'Producers': 'object',
    'Studios': 'object',
    'Source': 'object',
    'Time per ep (Min)': 'float64',
    'Rating': 'object',
    'Popularity': 'float64',
    'Favorites': 'float64',
    'Scored By': 'float64',  # "objeect -> int64" typo corrected
    'Members': 'float64',
    'Image URL': 'object',
})

# %%
raw_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13920 entries, 0 to 13919
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               13920 non-null  object
#  1   Score              13920 non-null  float64
#  2   Genres             13920 non-null  object
#  3   Synopsis           13920 non-null  object
#  4   Type               13920 non-null  object
#  5   Episodes           13920 non-null  float64
#  6   Producers          13920 non-null  object
#  7   Studios            13920 non-null  object
#  8   Source             13920 non-null  object
#  9   Time per ep (Min)  13920 non-null  float64
#  10  Rating             13920 non-null  object
#  11  Rank               13920 non-null  object
#  12  Popularity         13920 non-null  float64
#  13  Favorites          13920 non-null  float64
#  14  Scored By          13920 non-null  float64
#  15  Members            13920 non-null  float64
#  16  Image URL          13920 non-null  object
#  17  Released date      13920 non-null  object
#  18  Completed date     13920 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Filling value for Rank
# Rank được xếp theo số điểm, nhưng trong dataset ban đầu rank và số điểm không được sắp xếp chính xác. Vì vậy nhóm sẽ thực hiện sắp xếp lại Rank theo độ ưu tiên giảm dần các thuộc tính: Score, Scored By và Name
#
# Sử dụng Scored by do cột này không thiếu giá trị nào, đồng thời số điểm theo đánh giá sẽ có giá trị hơn nếu càng nhiều người đánh giá

# %%
# available_rows = raw_anime_df[raw_anime_df['Rank'] != 'UNKNOWN']

# Thêm một cột tạm để đánh dấu các giá trị 'UNKNOWN'
raw_anime_df['Score_numeric'] = pd.to_numeric(raw_anime_df['Score'], errors='coerce')

# Sắp xếp theo cột 'Rank_numeric' (giá trị số trước), sau đó theo cột 'Rank' gốc để giữ lại thứ tự đúng
raw_anime_df = raw_anime_df.sort_values(by=['Score_numeric', 'Score', 'Scored By', 'Name'], ascending=[False, False, False, True])

# Xóa cột tạm
raw_anime_df = raw_anime_df.drop(columns=['Score_numeric'])

# Tạo thứ tự tăng dần từ 1 đến số lượng dòng
raw_anime_df['Rank'] = range(1, len(raw_anime_df) + 1)

# %%
raw_anime_df
# Out:
#                                      Name  Score  \
# 6043     Fullmetal Alchemist: Brotherhood   9.10
# 6955                          Steins;Gate   9.07
# 13663           Bleach: Sennen Kessen-hen   9.07
# 9237                             Gintama°   9.06
# 11783  Shingeki no Kyojin Season 3 Part 2   9.05
# ...                                   ...    ...
# 9431                             Kokuhaku   2.30
# 4612                      Hametsu no Mars   2.22
# 3688                         Tsui no Sora   2.22
# 3797                   Utsu Musume Sayuri   1.98
# 4416         Tenkuu Danzai Skelter+Heaven   1.85
#
#                                   Genres  \
# 6043   Action, Adventure, Drama, Fantasy
# 6955             Drama, Sci-Fi, Suspense
# 13663         Action, Adventure, Fantasy
# 9237              Action, Comedy, Sci-Fi
# 11783                      Action, Drama
# ...                                  ...
# 9431                              Horror
# 4612                      Horror, Sci-Fi
# 3688                              Hentai
# 3797                 Avant Garde, Comedy
# 4416                              Sci-Fi
#
#                                                 Synopsis Type  Episodes  \
# 6043   After a horrific alchemy experiment goes wrong...   TV      64.0
# 6955   Eccentric scientist Rintarou Okabe has a never...   TV      24.0
# 13663  Substitute Soul Reaper Ichigo Kurosaki spends ...   TV      13.0
# 9237   Gintoki, Shinpachi, and Kagura return as the f...   TV      51.0
# 11783  Seeking to restore humanity's diminishing hope...   TV      10.0
# ...                                                  ...  ...       ...
# 9431   Beside a certain building, a girl appears to m...  ONA       1.0
# 4612   Several months after a probe returning from Ma...  OVA       1.0
# 3688   After the sudden death of a student, mysteriou...  OVA       1.0
# 3797   Sayuri is a curious creature who lives on her ...  OVA       1.0
# 4416   When a mysterious entity suddenly appears in t...  OVA       1.0
#
#                                                Producers  \
# 6043   Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 6955   Frontier Works, Media Factory, Kadokawa Shoten...
# 13663                TV Tokyo, Aniplex, Dentsu, Shueisha
# 9237                           TV Tokyo, Aniplex, Dentsu
# 11783  Production I.G, Dentsu, Mainichi Broadcasting ...
# ...                                                  ...
# 9431                                             UNKNOWN
# 4612          Idea Factory, King Records, Design Factory
# 3688                                       Obtain Future
# 3797                                             UNKNOWN
# 4416                                 Idea Factory, Cospa
#
#                       Studios        Source  Time per ep (Min)  \
# 6043                    Bones         Manga              24.00
# 6955                White Fox  Visual novel              24.00
# 13663                 Pierrot         Manga              24.00
# 9237    Bandai Namco Pictures         Manga              24.00
# 11783              Wit Studio         Manga              23.00
# ...                       ...           ...                ...
# 9431                  UNKNOWN      Original               0.67
# 4612                WAO World  Visual novel              19.00
# 3688                  UNKNOWN  Visual novel              23.00
# 3797                  UNKNOWN      Original               3.00
# 4416   Minami Machi Bugyousho          Game              19.00
#
#                                Rating   Rank  Popularity  Favorites  \
# 6043   R - 17+ (violence & profanity)      1         3.0   217606.0
# 6955        PG-13 - Teens 13 or older      2        13.0   182964.0
# 13663  R - 17+ (violence & profanity)      3       464.0    17999.0
# 9237        PG-13 - Teens 13 or older      4       331.0    15947.0
# 11783  R - 17+ (violence & profanity)      5        24.0    55245.0
# ...                               ...    ...         ...        ...
# 9431   R - 17+ (violence & profanity)  13916      7105.0       17.0
# 4612   R - 17+ (violence & profanity)  13917      2512.0      295.0
# 3688                      Rx - Hentai  13918      7563.0       24.0
# 3797                 R+ - Mild Nudity  13919      4492.0       50.0
# 4416        PG-13 - Teens 13 or older  13920      3415.0      111.0
#
#        Scored By    Members  \
# 6043   2020030.0  3176556.0
# 6955   1336233.0  2440369.0
# 13663   213872.0   445198.0
# 9237    237957.0   595767.0
# 11783  1471825.0  2104016.0
# ...          ...        ...
# 9431      4904.0     6697.0
# 4612     47630.0    65622.0
# 3688      3436.0     5713.0
# 3797     15873.0    20789.0
# 4416     26431.0    37328.0
#
#                                                Image URL Released date  \
# 6043   https://cdn.myanimelist.net/images/anime/1208/...    2009-04-05
# 6955   https://cdn.myanimelist.net/images/anime/1935/...    2011-04-06
# 13663  https://cdn.myanimelist.net/images/anime/1908/...    2022-10-11
# 9237   https://cdn.myanimelist.net/images/anime/3/720...    2015-04-08
# 11783  https://cdn.myanimelist.net/images/anime/1517/...    2019-04-29
# ...                                                  ...           ...
# 9431   https://cdn.myanimelist.net/images/anime/9/762...    2015-08-27
# 4612   https://cdn.myanimelist.net/images/anime/7/688...    2005-07-06
# 3688   https://cdn.myanimelist.net/images/anime/1179/...    2002-08-10
# 3797   https://cdn.myanimelist.net/images/anime/6/375...    2003-01-01
# 4416   https://cdn.myanimelist.net/images/anime/9/621...    2004-12-08
#
#       Completed date
# 6043      2010-07-04
# 6955      2011-09-14
# 13663     2022-12-27
# 9237      2016-03-30
# 11783     2019-07-01
# ...              ...
# 9431      2015-08-27
# 4612      2005-07-06
# 3688      2002-08-10
# 3797      2003-01-01
# 4416      2004-12-08
#
# [13920 rows x 19 columns]

# %% [markdown]
# ### Filling value for Premiered:
# Mùa anime được định nghĩa như sau:
# - Tháng 1, 2, 3: Winter
# - Tháng 4, 5, 6: Spring
# - Tháng 7, 8, 9: Summer
# - Tháng 10, 11, 12: Fall

# %%
# # Hàm xác định mùa dựa trên tháng
# def determine_season(month):
#     if month in [1, 2, 3]:
#         return "winter"
#     elif month in [4, 5, 6]:
#         return "spring"
#     elif month in [7, 8, 9]:
#         return "summer"
#     elif month in [10, 11, 12]:
#         return "fall"
#     return "unknown"

# # Hàm tạo giá trị Premiered
# def create_premiered(released_date):
#     if pd.isna(released_date):  # Kiểm tra giá trị NaN
#         return "unknown"
#     try:
#         # Thử với định dạng YYYY-MM-DD
#         date = pd.to_datetime(released_date, format="%Y-%m-%d")
#     except ValueError:
#         try:
#             # Nếu không được, thử với định dạng MM/DD/YYYY
#             date = pd.to_datetime(released_date, format="%m/%d/%Y")
#         except ValueError:
#             return "unknown"  # Nếu cả hai định dạng đều không hợp lệ

#     # Xác định mùa và năm
#     month = date.month
#     year = date.year
#     season = determine_season(month)
#     return f"{season} {year}"

# # Áp dụng hàm để tạo cột Premiered
# raw_anime_df['Premiered'] = raw_anime_df['Released date'].apply(create_premiered)
# raw_anime_df

# %%
# # Xem kết quả
# raw_anime_df = raw_anime_df.sort_values(by=['Released date'], ascending=[True])

# raw_anime_df.to_csv("anime-processed-date.csv", sep=',', encoding='utf-8-sig', index=False, header=True)

# %% [markdown]
# ### Handling type of attributes

# %%
raw_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13920 entries, 6043 to 4416
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               13920 non-null  object
#  1   Score              13920 non-null  float64
#  2   Genres             13920 non-null  object
#  3   Synopsis           13920 non-null  object
#  4   Type               13920 non-null  object
#  5   Episodes           13920 non-null  float64
#  6   Producers          13920 non-null  object
#  7   Studios            13920 non-null  object
#  8   Source             13920 non-null  object
#  9   Time per ep (Min)  13920 non-null  float64
#  10  Rating             13920 non-null  object
#  11  Rank               13920 non-null  int64
#  12  Popularity         13920 non-null  float64
#  13  Favorites          13920 non-null  float64
#  14  Scored By          13920 non-null  float64
#  15  Members            13920 non-null  float64
#  16  Image URL          13920 non-null  object
#  17  Released date      13920 non-null  object
#  18  Completed date     13920 non-null  object
# dtypes: float64(7), int64(1), object(11)
# memory usage: 2.1+ MB

# %% [markdown]
# Nhóm sẽ xử lí một vài kiểu dữ liệu sau để cho ra bộ dữ liệu tối ưu nhất:
# - Name: object
# - Score: float64
# - Genres: object
# - Synopsis: object
# - Type: object
# - Episodes: float64
# - Producers: object
# - Studios: object
# - Source: object
# - Time per ep (Min): float64
# - Rating: object
# - Rank: int64
# - Popularity: int64
# - Favourites: int64
# - Scored by: int64
# - Members: int64
# - Image URL: object
# - Released date: object
# - Completed date: object

# %%
# Chuyển kiểu dữ liệu:
raw_anime_df = raw_anime_df.astype({
    'Name': 'object',
    'Score': 'float64',
    'Genres': 'object',
    'Synopsis': 'object',
    'Type': 'object',
    'Episodes': 'float64',
    'Producers': 'object',
    'Studios': 'object',
    'Source': 'object',
    'Time per ep (Min)': 'float64',
    'Rating': 'object',
    'Popularity': 'int64',
    'Favorites': 'int64',
    'Scored By': 'int64',
    'Members': 'int64',
    'Image URL': 'object',
})

# %%
raw_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13920 entries, 6043 to 4416
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               13920 non-null  object
#  1   Score              13920 non-null  float64
#  2   Genres             13920 non-null  object
#  3   Synopsis           13920 non-null  object
#  4   Type               13920 non-null  object
#  5   Episodes           13920 non-null  float64
#  6   Producers          13920 non-null  object
#  7   Studios            13920 non-null  object
#  8   Source             13920 non-null  object
#  9   Time per ep (Min)  13920 non-null  float64
#  10  Rating             13920 non-null  object
#  11  Rank               13920 non-null  int64
#  12  Popularity         13920 non-null  int64
#  13  Favorites          13920 non-null  int64
#  14  Scored By          13920 non-null  int64
#  15  Members            13920 non-null  int64
#  16  Image URL          13920 non-null  object
#  17  Released date      13920 non-null  object
#  18  Completed date     13920 non-null  object
# dtypes: float64(3), int64(5), object(11)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Xuất ra file .csv

# %%
# Xem kết quả
raw_anime_df.to_csv("anime-data-preprocessing.csv", sep=',', encoding='utf-8-sig', index=False, header=True)

# %% [markdown]
# ### Kiểm tra file

# %%
raw_df = pd.read_csv('./anime-data-preprocessing.csv')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13920 entries, 0 to 13919
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               13920 non-null  object
#  1   Score              13920 non-null  float64
#  2   Genres             13920 non-null  object
#  3   Synopsis           13920 non-null  object
#  4   Type               13920 non-null  object
#  5   Episodes           13920 non-null  float64
#  6   Producers          13920 non-null  object
#  7   Studios            13920 non-null  object
#  8   Source             13920 non-null  object
#  9   Time per ep (Min)  13920 non-null  float64
#  10  Rating             13920 non-null  object
#  11  Rank               13920 non-null  int64
#  12  Popularity         13920 non-null  int64
#  13  Favorites          13920 non-null  int64
#  14  Scored By          13920 non-null  int64
#  15  Members            13920 non-null  int64
#  16  Image URL          13920 non-null  object
#  17  Released date      13920 non-null  object
#  18  Completed date     13920 non-null  object
# dtypes: float64(3), int64(5), object(11)
# memory usage: 2.0+ MB

# %%
# Đếm số lượng "UNKNOWN" trong từng cột
unknown_count_per_column = ((raw_anime_df == 'UNKNOWN') | (raw_anime_df == 'Unknown')).sum()

# Xem kết quả
print("Số lượng 'UNKNOWN' trong từng cột:")
print(unknown_count_per_column)
# Out:
# Số lượng 'UNKNOWN' trong từng cột:
# Name                    0
# Score                   0
# Genres                  0
# Synopsis                0
# Type                    0
# Episodes                0
# Producers            5063
# Studios              2371
# Source               1540
# Time per ep (Min)       0
# Rating                 86
# Rank                    0
# Popularity              0
# Favorites               0
# Scored By               0
# Members                 0
# Image URL               0
# Released date           0
# Completed date          0
# dtype: int64
